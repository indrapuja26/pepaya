# %% [markdown]
# <a href="https://colab.research.google.com/github/indrapuja26/pepaya/blob/main/pepaya/image_fundamental/split_merge.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !wget https://raw.githubusercontent.com/indrapuja26/pepaya/main/pepaya%20003.jpg --no-check-certificate
# Out:
# --2021-11-09 15:09:17--  https://raw.githubusercontent.com/indrapuja26/pepaya/main/pepaya%20003.jpg
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 50034 (49K) [image/jpeg]
# Saving to: ‘pepaya 003.jpg’
#
# pepaya 003.jpg      100%[===================>]  48.86K  --.-KB/s    in 0.006s
#
# 2021-11-09 15:09:18 (8.20 MB/s) - ‘pepaya 003.jpg’ saved [50034/50034]

# %%
# import the necessary packages
from matplotlib import pyplot as plt
import numpy as np
import argparse
import cv2

# %%
def plt_imshow(title, image):
	# convert the image frame BGR to RGB color space and display it
	image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
	plt.imshow(image)
	plt.title(title)
	plt.grid(False)
	plt.show()

# %%
# since we are using Jupyter Notebooks we can replace our argument
# parsing code with *hard coded* arguments and values
args = {
	"image": "pepaya 003.jpg"
}

# %%
# load the input image and grab each channel -- note how OpenCV
# represents images as NumPy arrays with channels in Blue, Green,
# Red ordering rather than Red, Green Blue
image = cv2.imread(args["image"])
(B, G, R) = cv2.split(image)

# show each channel individually
plt_imshow("Red", R)
plt_imshow("Green", G)
plt_imshow("Blue", B)

# %% [markdown]
# <a href="https://colab.research.google.com/github/indrapuja26/pepaya/blob/main/neural_network.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Download dataset
# !wget --no-check-certificate \
    https://raw.githubusercontent.com/indrapuja26/pepaya/main/jambu_biji_and_pepaya_filtered.zip \
    -O /tmp/jambu_biji_and_pepaya_filtered.zip
# Out:
# --2021-11-16 15:56:26--  https://raw.githubusercontent.com/indrapuja26/pepaya/main/jambu_biji_and_pepaya_filtered.zip
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 4121893 (3.9M) [application/zip]
# Saving to: ‘/tmp/jambu_biji_and_pepaya_filtered.zip’
#
# /tmp/jambu_biji_and 100%[===================>]   3.93M  --.-KB/s    in 0.08s
#
# 2021-11-16 15:56:26 (51.1 MB/s) - ‘/tmp/jambu_biji_and_pepaya_filtered.zip’ saved [4121893/4121893]

# %%
import os
import zipfile

local_zip = '/tmp/jambu_biji_and_pepaya_filtered.zip'
zip_ref = zipfile.ZipFile(local_zip, 'r')
zip_ref.extractall('/tmp')
zip_ref.close()

# %%
base_dir = '/tmp/jambu_biji_and_pepaya_filtered'

train_dir = os.path.join(base_dir, 'train')
validation_dir = os.path.join(base_dir, 'validation')

train_pepaya_dir = os.path.join(train_dir, 'pepaya')
train_jambu_biji_dir = os.path.join(train_dir, 'jambu_biji')

validation_pepaya_dir = os.path.join(validation_dir, 'pepaya')
validation_jambu_biji_dir = os.path.join(validation_dir, 'jambu_biji')

# %%
# Cek penamaan image yang ada di folder train_cats_dir dan train_dogs_dir
print(os.listdir(train_pepaya_dir)[:10])
print(os.listdir(train_jambu_biji_dir)[:10])
# Out:
# ['pepaya 035.jpg', 'pepaya 002.jpg', 'pepaya 023.jpg', 'pepaya 019.jpg', 'pepaya 021.jpg', 'pepaya 012.jpg', 'pepaya 007.jpg', 'pepaya 005.jpg', 'pepaya 022.jpg', 'pepaya 039.jpg']
# ['jambu biji 021.jpg', 'jambu biji 035.jpg', 'jambu biji 002.jpg', 'jambu biji 030.jpg', 'jambu biji 015.jpg', 'jambu biji 026.jpg', 'jambu biji 036.jpg', 'jambu biji 014.jpg', 'jambu biji 039.jpg', 'jambu biji 040.jpg']

# %%
# Cek jumlah data train dan data validation
print('total training pepaya images:', len(os.listdir(train_pepaya_dir)))
print('total training jambu_biji images:', len(os.listdir(train_jambu_biji_dir)))
print('total validation pepaya images:', len(os.listdir(validation_pepaya_dir)))
print('total validation jambu_biji images:', len(os.listdir(validation_jambu_biji_dir)))
# Out:
# total training pepaya images: 40
# total training jambu_biji images: 40
# total validation pepaya images: 10
# total validation jambu_biji images: 10

# %%
# Tampilkan 8 image per kelas dengan ukuran 4x4 

# %matplotlib inline

import matplotlib.pyplot as plt
import matplotlib.image as mpimg

nrows = 4
ncols = 4

pic_index = 0

fig = plt.gcf()
fig.set_size_inches(ncols * 4, nrows * 4)

pic_index += 8
next_cat_pix = [os.path.join(train_pepaya_dir, fname) 
                for fname in os.listdir(train_pepaya_dir)[pic_index-8:pic_index]]
next_dog_pix = [os.path.join(train_jambu_biji_dir, fname) 
                for fname in os.listdir(train_jambu_biji_dir)[pic_index-8:pic_index]]

for i, img_path in enumerate(next_cat_pix+next_dog_pix):
  # Set up subplot; subplot indices start at 1
  sp = plt.subplot(nrows, ncols, i + 1)
  sp.axis('Off') # Don't show axes (or gridlines)

  img = mpimg.imread(img_path)
  plt.imshow(img)

plt.show()

# %%
import cv2
import numpy as np

# Gather data train
train_data = []
train_label = []
for r, d, f in os.walk(train_dir):
    for file in f:
        if ".jpg" in file:
            imagePath = os.path.join(r, file)
            image = cv2.imread(imagePath)
            image = cv2.resize(image, (150,150))
            train_data.append(image)
            label = imagePath.split(os.path.sep)[-2]
            train_label.append(label)

train_data = np.array(train_data)
train_label = np.array(train_label)

# %%
# Gather data validation
val_data = []
val_label = []
for r, d, f in os.walk(validation_dir):
    for file in f:
        if ".jpg" in file:
            imagePath = os.path.join(r, file)
            image = cv2.imread(imagePath)
            image = cv2.resize(image, (150,150))
            val_data.append(image)
            label = imagePath.split(os.path.sep)[-2]
            val_label.append(label)

val_data = np.array(val_data)
val_label = np.array(val_label)

# %%
# Tampilkan shape dari data train dan data validation
print("Train Data = ", train_data.shape)
print("Train Label = ", train_label.shape)
print("Validation Data = ", val_data.shape)
print("Validation Label = ", val_label.shape)

# %%
# Normalisasi dataset
print("Data sebelum di-normalisasi ", train_data[0][0][0])

x_train = train_data.astype('float32') / 255.0
x_val = val_data.astype('float32') / 255.0
print("Data setelah di-normalisasi ", x_train[0][0][0])
# Out:
# Data sebelum di-normalisasi  [244 244 244]
# Data setelah di-normalisasi  [0.95686275 0.95686275 0.95686275]

# %%
# Transformasi label encoder
from sklearn.preprocessing import LabelEncoder

print("Label sebelum di-encoder ", train_label[995:1005])

lb = LabelEncoder()
y_train = lb.fit_transform(train_label)
y_val = lb.fit_transform(val_label)

print("Label setelah di-encoder ", y_train[995:1005])
# Out:
# Label sebelum di-encoder  []
# Label setelah di-encoder  []

# %%
from tensorflow.keras import layers
from tensorflow.keras import Model

# %%
# Buat model dengan 1 input layer, 1 hidden layer, dan 1 output layer
img_input = layers.Input(shape=(150, 150, 3)) # layer input
x = layers.Flatten()(img_input) # ubah dari matriks 150x150x3 menjadi vektor
x = layers.Dense(128, activation='relu')(x) # hidden layer 1 dengan 128 neuron
output = layers.Dense(1, activation='sigmoid')(x) # output layer dengan 1 neuron (binary)

# Definisikan modelnya
model = Model(img_input, output)

# %%
# Tampilkan model summary
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 150, 150, 3)]     0
#
#  flatten (Flatten)           (None, 67500)             0
#
#  dense (Dense)               (None, 128)               8640128
#
#  dense_1 (Dense)             (None, 1)                 129
#
# =================================================================
# Total params: 8,640,257
# Trainable params: 8,640,257
# Non-trainable params: 0
# _________________________________________________________________

# %%
from tensorflow.keras.optimizers import Adam

# Compile model
model.compile(loss='binary_crossentropy',
              optimizer=Adam(lr=0.001),
              metrics=['acc'])
# Out:
# /usr/local/lib/python3.7/dist-packages/keras/optimizer_v2/adam.py:105: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)

# %%
H = model.fit(x_train, y_train, batch_size=20, epochs=50, validation_data=(x_val, y_val))
# Out:
# Epoch 1/50
# 4/4 [==============================] - 1s 130ms/step - loss: 25.5991 - acc: 0.5500 - val_loss: 26.3049 - val_acc: 0.5000
# Epoch 2/50
# 4/4 [==============================] - 0s 71ms/step - loss: 14.0106 - acc: 0.6000 - val_loss: 22.6344 - val_acc: 0.5000
# Epoch 3/50
# 4/4 [==============================] - 0s 75ms/step - loss: 10.3335 - acc: 0.6375 - val_loss: 9.0346 - val_acc: 0.5000
# Epoch 4/50
# 4/4 [==============================] - 0s 75ms/step - loss: 4.6486 - acc: 0.6625 - val_loss: 4.7334 - val_acc: 0.7000
# Epoch 5/50
# 4/4 [==============================] - 0s 73ms/step - loss: 3.2059 - acc: 0.7000 - val_loss: 1.2023 - val_acc: 0.9000
# Epoch 6/50
# 4/4 [==============================] - 0s 72ms/step - loss: 1.0727 - acc: 0.8875 - val_loss: 2.5151 - val_acc: 0.7000
# Epoch 7/50
# 4/4 [==============================] - 0s 70ms/step - loss: 0.5351 - acc: 0.9250 - val_loss: 1.6920 - val_acc: 0.9000
# Epoch 8/50
# 4/4 [==============================] - 0s 74ms/step - loss: 0.7629 - acc: 0.9125 - val_loss: 1.6843 - val_acc: 0.9000
# Epoch 9/50
# 4/4 [==============================] - 0s 71ms/step - loss: 0.2562 - acc: 0.9750 - val_loss: 0.8704 - val_acc: 0.8500
# Epoch 10/50
# 4/4 [==============================] - 0s 78ms/step - loss: 0.4194 - acc: 0.9375 - val_loss: 0.5083 - val_acc: 0.9000
# Epoch 11/50
# 4/4 [==============================] - 0s 71ms/step - loss: 0.1461 - acc: 0.9875 - val_loss: 0.8507 - val_acc: 0.9000
# Epoch 12/50
# 4/4 [==============================] - 0s 73ms/step - loss: 0.0879 - acc: 0.9750 - val_loss: 1.0191 - val_acc: 0.9000
# Epoch 13/50
# 4/4 [==============================] - 0s 72ms/step - loss: 0.0513 - acc: 0.9750 - val_loss: 0.4229 - val_acc: 0.9500
# Epoch 14/50
# 4/4 [==============================] - 0s 75ms/step - loss: 0.0477 - acc: 0.9875 - val_loss: 0.3176 - val_acc: 0.9500
# Epoch 15/50
# 4/4 [==============================] - 0s 70ms/step - loss: 0.0042 - acc: 1.0000 - val_loss: 0.5161 - val_acc: 0.9500
# Epoch 16/50
# 4/4 [==============================] - 0s 73ms/step - loss: 0.0052 - acc: 1.0000 - val_loss: 0.7768 - val_acc: 0.9000
# Epoch 17/50
# 4/4 [==============================] - 0s 71ms/step - loss: 0.0054 - acc: 1.0000 - val_loss: 0.7311 - val_acc: 0.9000
# Epoch 18/50
# 4/4 [==============================] - 0s 69ms/step - loss: 7.0902e-04 - acc: 1.0000 - val_loss: 0.5255 - val_acc: 0.9500
# Epoch 19/50
# 4/4 [==============================] - 0s 73ms/step - loss: 5.1845e-04 - acc: 1.0000 - val_loss: 0.4080 - val_acc: 0.9500
# Epoch 20/50
# 4/4 [==============================] - 0s 70ms/step - loss: 8.3567e-04 - acc: 1.0000 - val_loss: 0.3520 - val_acc: 0.9500
# Epoch 21/50
# 4/4 [==============================] - 0s 72ms/step - loss: 8.5831e-04 - acc: 1.0000 - val_loss: 0.3566 - val_acc: 0.9500
# Epoch 22/50
# 4/4 [==============================] - 0s 72ms/step - loss: 5.6712e-04 - acc: 1.0000 - val_loss: 0.3740 - val_acc: 0.9500
# Epoch 23/50
# 4/4 [==============================] - 0s 74ms/step - loss: 2.7642e-04 - acc: 1.0000 - val_loss: 0.3924 - val_acc: 0.9500
# Epoch 24/50
# 4/4 [==============================] - 0s 75ms/step - loss: 2.0031e-04 - acc: 1.0000 - val_loss: 0.4148 - val_acc: 0.9500
# Epoch 25/50
# 4/4 [==============================] - 0s 71ms/step - loss: 1.3637e-04 - acc: 1.0000 - val_loss: 0.4342 - val_acc: 0.9500
# Epoch 26/50
# 4/4 [==============================] - 0s 74ms/step - loss: 1.2941e-04 - acc: 1.0000 - val_loss: 0.4527 - val_acc: 0.9500
# Epoch 27/50
# 4/4 [==============================] - 0s 71ms/step - loss: 1.1155e-04 - acc: 1.0000 - val_loss: 0.4665 - val_acc: 0.9500
# Epoch 28/50
# 4/4 [==============================] - 0s 73ms/step - loss: 1.0679e-04 - acc: 1.0000 - val_loss: 0.4759 - val_acc: 0.9500
# Epoch 29/50
# 4/4 [==============================] - 0s 72ms/step - loss: 1.1208e-04 - acc: 1.0000 - val_loss: 0.4833 - val_acc: 0.9500
# Epoch 30/50
# 4/4 [==============================] - 0s 70ms/step - loss: 1.0876e-04 - acc: 1.0000 - val_loss: 0.4855 - val_acc: 0.9500
# Epoch 31/50
# 4/4 [==============================] - 0s 70ms/step - loss: 1.0690e-04 - acc: 1.0000 - val_loss: 0.4846 - val_acc: 0.9500
# Epoch 32/50
# 4/4 [==============================] - 0s 72ms/step - loss: 1.0583e-04 - acc: 1.0000 - val_loss: 0.4822 - val_acc: 0.9500
# Epoch 33/50
# 4/4 [==============================] - 0s 74ms/step - loss: 1.0396e-04 - acc: 1.0000 - val_loss: 0.4782 - val_acc: 0.9500
# Epoch 34/50
# 4/4 [==============================] - 0s 73ms/step - loss: 1.0112e-04 - acc: 1.0000 - val_loss: 0.4750 - val_acc: 0.9500
# Epoch 35/50
# 4/4 [==============================] - 0s 72ms/step - loss: 9.8975e-05 - acc: 1.0000 - val_loss: 0.4725 - val_acc: 0.9500
# Epoch 36/50
# 4/4 [==============================] - 0s 71ms/step - loss: 1.0031e-04 - acc: 1.0000 - val_loss: 0.4673 - val_acc: 0.9500
# Epoch 37/50
# 4/4 [==============================] - 0s 71ms/step - loss: 9.6514e-05 - acc: 1.0000 - val_loss: 0.4649 - val_acc: 0.9500
# Epoch 38/50
# 4/4 [==============================] - 0s 72ms/step - loss: 9.5543e-05 - acc: 1.0000 - val_loss: 0.4630 - val_acc: 0.9500
# Epoch 39/50
# 4/4 [==============================] - 0s 74ms/step - loss: 9.4589e-05 - acc: 1.0000 - val_loss: 0.4618 - val_acc: 0.9500
# Epoch 40/50
# 4/4 [==============================] - 0s 72ms/step - loss: 9.4190e-05 - acc: 1.0000 - val_loss: 0.4604 - val_acc: 0.9500
# Epoch 41/50
# 4/4 [==============================] - 0s 75ms/step - loss: 9.3246e-05 - acc: 1.0000 - val_loss: 0.4607 - val_acc: 0.9500
# Epoch 42/50
# 4/4 [==============================] - 0s 70ms/step - loss: 9.2528e-05 - acc: 1.0000 - val_loss: 0.4602 - val_acc: 0.9500
# Epoch 43/50
# 4/4 [==============================] - 0s 74ms/step - loss: 9.1858e-05 - acc: 1.0000 - val_loss: 0.4594 - val_acc: 0.9500
# Epoch 44/50
# 4/4 [==============================] - 0s 69ms/step - loss: 9.1225e-05 - acc: 1.0000 - val_loss: 0.4587 - val_acc: 0.9500
# Epoch 45/50
# 4/4 [==============================] - 0s 73ms/step - loss: 9.0931e-05 - acc: 1.0000 - val_loss: 0.4597 - val_acc: 0.9500
# Epoch 46/50
# 4/4 [==============================] - 0s 70ms/step - loss: 9.0350e-05 - acc: 1.0000 - val_loss: 0.4587 - val_acc: 0.9500
# Epoch 47/50
# 4/4 [==============================] - 0s 71ms/step - loss: 8.9216e-05 - acc: 1.0000 - val_loss: 0.4582 - val_acc: 0.9500
# Epoch 48/50
# 4/4 [==============================] - 0s 72ms/step - loss: 8.7953e-05 - acc: 1.0000 - val_loss: 0.4591 - val_acc: 0.9500
# Epoch 49/50
# 4/4 [==============================] - 0s 72ms/step - loss: 8.7932e-05 - acc: 1.0000 - val_loss: 0.4587 - val_acc: 0.9500
# Epoch 50/50
# 4/4 [==============================] - 0s 71ms/step - loss: 8.6552e-05 - acc: 1.0000 - val_loss: 0.4598 - val_acc: 0.9500

# %%
plt.style.use("ggplot")
plt.figure()
plt.plot(np.arange(0, 50), H.history["loss"], label="train_loss")
plt.plot(np.arange(0, 50), H.history["val_loss"], label="val_loss")
plt.title("Loss Plot")
plt.xlabel("Epoch #")
plt.ylabel("Loss")
plt.legend()
plt.show()

# %%
plt.style.use("ggplot")
plt.figure()
plt.plot(np.arange(0, 50), H.history["acc"], label="train_acc")
plt.plot(np.arange(0, 50), H.history["val_acc"], label="val_acc")
plt.title("Accuracy Plot")
plt.xlabel("Epoch #")
plt.ylabel("Acc")
plt.legend()
plt.show()

# %%
from sklearn.metrics import classification_report

pred = model.predict(x_val)
labels = (pred > 0.5).astype(np.int)

print(classification_report(y_val, labels))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      0.90      0.95        10
#            1       0.91      1.00      0.95        10
#
#     accuracy                           0.95        20
#    macro avg       0.95      0.95      0.95        20
# weighted avg       0.95      0.95      0.95        20
